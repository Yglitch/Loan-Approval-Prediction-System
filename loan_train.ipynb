# %% [markdown]
# # importing the library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pyplot as mpl
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score,KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

import joblib

# %% [markdown]
# # Load the dataset

# %%
df = pd.read_csv("dataset/loan_approval_dataset.csv")
df
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0         29900000          12           778                    2400000
# 1         12200000           8           417                    2700000
# 2         29700000          20           506                    7100000
# 3         30700000           8           467                   18200000
# 4         24200000          20           382                   12400000
# ...            ...         ...           ...                        ...
# 4264       2300000          12           317                    2800000
# 4265      11300000          20           559                    4200000
# 4266      23900000          18           457                    1200000
# 4267      12800000           8           780                    8200000
# 4268      29700000          10           607                   17800000
#
#        commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                     17600000              22700000            8000000
# 1                      2200000               8800000            3300000
# 2                      4500000              33300000           12800000
# 3                      3300000              23300000            7900000
# 4                      8200000              29400000            5000000
# ...                        ...                   ...                ...
# 4264                    500000               3300000             800000
# 4265                   2900000              11000000            1900000
# 4266                  12400000              18100000            7300000
# 4267                    700000              14100000            5800000
# 4268                  11800000              35700000           12000000
#
#       loan_status
# 0        Approved
# 1        Rejected
# 2        Rejected
# 3        Rejected
# 4        Rejected
# ...           ...
# 4264     Rejected
# 4265     Approved
# 4266     Rejected
# 4267     Approved
# 4268     Approved
#
# [4269 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   str
#  3    self_employed             4269 non-null   str
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   str
# dtypes: int64(10), str(3)
# memory usage: 433.7 KB

# %% [markdown]
# ### Check dataset information

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %% [markdown]
# ### View last 5 rows

# %% [markdown]
# ### check Statistical summary

# %%
df.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# 25%       6.000000    453.000000               2.200000e+06
# 50%      10.000000    600.000000               5.600000e+06
# 75%      16.000000    748.000000               1.130000e+07
# max      20.000000    900.000000               2.910000e+07
#
#         commercial_assets_value   luxury_assets_value   bank_asset_value
# count              4.269000e+03          4.269000e+03       4.269000e+03
# mean               4.973155e+06          1.512631e+07       4.976692e+06
# std                4.388966e+06          9.103754e+06       3.250185e+06
# min                0.000000e+00          3.000000e+05       0.000000e+00
# 25%                1.300000e+06          7.500000e+06       2.300000e+06
# 50%                3.700000e+06          1.460000e+07       4.600000e+06
# 75%                7.600000e+06          2.170000e+07       7.100000e+06
# max                1.940000e+07          3.920000e+07       1.470000e+07

# %% [markdown]
# ### Check dataset shape

# %%
df.shape
# Out:
# (4269, 13)

# %% [markdown]
# ### Check if there is any missing values

# %%
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.columns = df.columns.str.strip()

# %%
df["loan_status"].value_counts()
# Out:
# loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64

# %% [markdown]
# # label encoding

# %%
le=LabelEncoder()

# %%
df["loan_status"]=le.fit_transform(df[["loan_status"]])
# Out:
# /home/yash-rama/Loan-Approval-Prediction-System/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:120: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df
# Out:
#       loan_id  no_of_dependents      education self_employed  income_annum  \
# 0           1                 2       Graduate            No       9600000
# 1           2                 0   Not Graduate           Yes       4100000
# 2           3                 3       Graduate            No       9100000
# 3           4                 3       Graduate            No       8200000
# 4           5                 5   Not Graduate           Yes       9800000
# ...       ...               ...            ...           ...           ...
# 4264     4265                 5       Graduate           Yes       1000000
# 4265     4266                 0   Not Graduate           Yes       3300000
# 4266     4267                 2   Not Graduate            No       6500000
# 4267     4268                 1   Not Graduate            No       4100000
# 4268     4269                 1       Graduate            No       9200000
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0        29900000         12          778                   2400000
# 1        12200000          8          417                   2700000
# 2        29700000         20          506                   7100000
# 3        30700000          8          467                  18200000
# 4        24200000         20          382                  12400000
# ...           ...        ...          ...                       ...
# 4264      2300000         12          317                   2800000
# 4265     11300000         20          559                   4200000
# 4266     23900000         18          457                   1200000
# 4267     12800000          8          780                   8200000
# 4268     29700000         10          607                  17800000
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value  \
# 0                    17600000             22700000           8000000
# 1                     2200000              8800000           3300000
# 2                     4500000             33300000          12800000
# 3                     3300000             23300000           7900000
# 4                     8200000             29400000           5000000
# ...                       ...                  ...               ...
# 4264                   500000              3300000            800000
# 4265                  2900000             11000000           1900000
# 4266                 12400000             18100000           7300000
# 4267                   700000             14100000           5800000
# 4268                 11800000             35700000          12000000
#
#       loan_status
# 0               0
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 4264            1
# 4265            0
# 4266            1
# 4267            0
# 4268            0
#
# [4269 rows x 13 columns]

# %%
label_encoders ={}

# %%
for col in df.select_dtypes(include="object").columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le
# Out:
# /tmp/ipykernel_9868/715676355.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in df.select_dtypes(include="object").columns:

# %%
joblib.dump(label_encoders,"label_encoding.pkl")
# Out:
# ['label_encoding.pkl']

# %%
df
# Out:
#       loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0           1                 2          0              0       9600000
# 1           2                 0          1              1       4100000
# 2           3                 3          0              0       9100000
# 3           4                 3          0              0       8200000
# 4           5                 5          1              1       9800000
# ...       ...               ...        ...            ...           ...
# 4264     4265                 5          0              1       1000000
# 4265     4266                 0          1              1       3300000
# 4266     4267                 2          1              0       6500000
# 4267     4268                 1          1              0       4100000
# 4268     4269                 1          0              0       9200000
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0        29900000         12          778                   2400000
# 1        12200000          8          417                   2700000
# 2        29700000         20          506                   7100000
# 3        30700000          8          467                  18200000
# 4        24200000         20          382                  12400000
# ...           ...        ...          ...                       ...
# 4264      2300000         12          317                   2800000
# 4265     11300000         20          559                   4200000
# 4266     23900000         18          457                   1200000
# 4267     12800000          8          780                   8200000
# 4268     29700000         10          607                  17800000
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value  \
# 0                    17600000             22700000           8000000
# 1                     2200000              8800000           3300000
# 2                     4500000             33300000          12800000
# 3                     3300000             23300000           7900000
# 4                     8200000             29400000           5000000
# ...                       ...                  ...               ...
# 4264                   500000              3300000            800000
# 4265                  2900000             11000000           1900000
# 4266                 12400000             18100000           7300000
# 4267                   700000             14100000           5800000
# 4268                 11800000             35700000          12000000
#
#       loan_status
# 0               0
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 4264            1
# 4265            0
# 4266            1
# 4267            0
# 4268            0
#
# [4269 rows x 13 columns]

# %%
X = df.drop(df[["loan_id","loan_status"]],axis='columns')  
y = df["loan_status"]

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=.2)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

x_train_scaled = scaler.fit_transform(x_train)   # fit only on train
x_test_scaled = scaler.transform(x_test)          # only transform test, don't re-fit

joblib.dump(scaler, "scaler.joblib")
# Out:
# ['scaler.joblib']

# %%
x_train_scaled
# Out:
# array([[0.8       , 0.        , 0.        , ..., 0.33505155, 0.38817481,
#         0.52380952],
#        [0.2       , 0.        , 0.        , ..., 0.48969072, 0.4781491 ,
#         0.60544218],
#        [0.2       , 1.        , 0.        , ..., 0.24742268, 0.41131105,
#         0.47619048],
#        ...,
#        [0.4       , 0.        , 0.        , ..., 0.19072165, 0.16709512,
#         0.17687075],
#        [0.2       , 1.        , 1.        , ..., 0.63402062, 0.44730077,
#         0.53061224],
#        [0.6       , 0.        , 1.        , ..., 0.55670103, 0.49100257,
#         0.65306122]], shape=(3415, 11))

# %%
k=KFold(n_splits=5)

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Random Forest": RandomForestClassifier(n_estimators=300, max_depth=8, random_state=42),
    "SVC": SVC(kernel="rbf", gamma='auto', random_state=42)
}

scores = {}

for name, model in models.items():
    cv_score= cross_val_score(model,x_train_scaled,y_train,cv=k)
    scores[name]= cv_score.mean()

    print(name,"=",cv_score)
    print("-"*40)
# Out:
# Logistic Regression = [0.91068814 0.90775988 0.92679356 0.91800878 0.90629575]
# ----------------------------------------
# Random Forest = [0.96486091 0.95754026 0.97364568 0.97510981 0.98243045]
# ----------------------------------------
# SVC = [0.9238653  0.91654466 0.92532943 0.92825769 0.91508053]
# ----------------------------------------

# %%
scores
# Out:
# {'Logistic Regression': np.float64(0.9139092240117132),
#  'Random Forest': np.float64(0.9707174231332358),
#  'SVC': np.float64(0.9218155197657394)}

# %%
# hence random forest is selected

# %% [markdown]
# ### PLotting a histogram between two columns(cibil_score , Graduation , Loan_term - Loan_status)

# %%
plt.figure(figsize=(8,5))

sns.violinplot(
    data=df,
    x='loan_status',
    y='cibil_score'
)

plt.title("Cibil Score Distribution by Loan Status")
plt.show()

# %% [markdown]
# ### Visualizing the confusion matrix for Random Forest Classifier

# %%
corr = df.corr()
corr
# Out:
#                            loan_id  no_of_dependents  education  \
# loan_id                   1.000000          0.005326  -0.015536
# no_of_dependents          0.005326          1.000000  -0.002697
# education                -0.015536         -0.002697   1.000000
# self_employed             0.001745          0.000765   0.023224
# income_annum              0.012592          0.007266  -0.011625
# loan_amount               0.008170         -0.003366  -0.010631
# loan_term                 0.009809         -0.020111   0.008417
# cibil_score               0.016323         -0.009998   0.004649
# residential_assets_value  0.020936          0.007376  -0.010930
# commercial_assets_value   0.018595         -0.001531   0.006763
# luxury_assets_value      -0.000862          0.002817  -0.012471
# bank_asset_value          0.010765          0.011163  -0.009424
# loan_status              -0.017685          0.018114   0.004918
#
#                           self_employed  income_annum  loan_amount  loan_term  \
# loan_id                        0.001745      0.012592     0.008170   0.009809
# no_of_dependents               0.000765      0.007266    -0.003366  -0.020111
# education                      0.023224     -0.011625    -0.010631   0.008417
# self_employed                  1.000000      0.002368     0.001450   0.004107
# income_annum                   0.002368      1.000000     0.927470   0.011488
# loan_amount                    0.001450      0.927470     1.000000   0.008437
# loan_term                      0.004107      0.011488     0.008437   1.000000
# cibil_score                   -0.004866     -0.023034    -0.017035   0.007810
# residential_assets_value       0.006144      0.636841     0.594596   0.008016
# commercial_assets_value       -0.017998      0.640328     0.603188  -0.005478
# luxury_assets_value            0.004413      0.929145     0.860914   0.012490
# bank_asset_value              -0.000215      0.851093     0.788122   0.017177
# loan_status                   -0.000345      0.015189    -0.016150   0.113036
#
#                           cibil_score  residential_assets_value  \
# loan_id                      0.016323                  0.020936
# no_of_dependents            -0.009998                  0.007376
# education                    0.004649                 -0.010930
# self_employed               -0.004866                  0.006144
# income_annum                -0.023034                  0.636841
# loan_amount                 -0.017035                  0.594596
# loan_term                    0.007810                  0.008016
# cibil_score                  1.000000                 -0.019947
# residential_assets_value    -0.019947                  1.000000
# commercial_assets_value     -0.003769                  0.414786
# luxury_assets_value         -0.028618                  0.590932
# bank_asset_value            -0.015478                  0.527418
# loan_status                 -0.770518                  0.014367
#
#                           commercial_assets_value  luxury_assets_value  \
# loan_id                                  0.018595            -0.000862
# no_of_dependents                        -0.001531             0.002817
# education                                0.006763            -0.012471
# self_employed                           -0.017998             0.004413
# income_annum                             0.640328             0.929145
# loan_amount                              0.603188             0.860914
# loan_term                               -0.005478             0.012490
# cibil_score                             -0.003769            -0.028618
# residential_assets_value                 0.414786             0.590932
# commercial_assets_value                  1.000000             0.591128
# luxury_assets_value                      0.591128             1.000000
# bank_asset_value                         0.548576             0.788517
# loan_status                             -0.008246             0.015465
#
#                           bank_asset_value  loan_status
# loan_id                           0.010765    -0.017685
# no_of_dependents                  0.011163     0.018114
# education                        -0.009424     0.004918
# self_employed                    -0.000215    -0.000345
# income_annum                      0.851093     0.015189
# loan_amount                       0.788122    -0.016150
# loan_term                         0.017177     0.113036
# cibil_score                      -0.015478    -0.770518
# residential_assets_value          0.527418     0.014367
# commercial_assets_value           0.548576    -0.008246
# luxury_assets_value               0.788517     0.015465
# bank_asset_value                  1.000000     0.006778
# loan_status                       0.006778     1.000000

# %%
plt.figure(figsize=(10, 8))

sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.1
)

plt.title("Correlation Heatmap")

plt.show()
